# %%
from scipy.optimize import minimize
import pandas as pd
import random

# %%
def gen_alg(df, n, S, Velocity, l, w, h, stop_score, max_epochs = 30, actual_score = None, generation = None,
            best_score = None, best_generation = None):
    
    for epoch in range(max_epochs):
        generation = new_generation(df, n, S, Velocity, l, w, h, generation)
        coeffs = [k['prob'] for k in generation]
        actual_score = calculate_score(coeffs)
        
        if actual_score>=stop_score: #<= в зависимости от того какой скор считать и какие знаечение стопом назначим, крч в какую сторону движется
            break
        
        if best_score == None or actual_score > best_score:
            best_score = actual_score
            best_generation = generation
    
    return best_generation, best_score


def generate_first_epoch(n): #генерация первого замощения(0 эпоха)
    pass
    
    
def mutation_bias(prob): #возвращает коэффициенты, некоторые из которых заменяны на рандомные числа некоторой функции
    pass


def calculate_score(coeffs): #!!!!!!!! основная функция замощения с расчётом скора покрытия 
    pass


def euclidean_distance(p1, p2): #а зачем это надо..... а, для расчёта примлегого расстояния между 2 роутерами
    return math.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)


def crossover(a, b, index): #генерация потомка (коэффициентов)
    return [b['coeffs'][:index] + a['coeffs'][index:], a['coeffs'][:index] + b['coeffs'][index:]]


def who_will_survive(probs): #определение индекса выжившего потомка в паре 2 родителей
    return random.choices([ind for i in range(len(probs))], probs)
    

def get_error(global_minimum, coeffs): #функция ошибки которую мы минимизируем относительно "идеального" значения (S/Velocity^2)
    return global_minimum - calculate_score(coeffs)
    

def optimized_probs(children):
    sum_error = 0
    
    for child in children:
        sum_error+=1/get_error(children)
        
    probs = []
    
    for child in children:
        probs.append((1/get_error(children)) / sum_error)
    
    return probs
        

    
def new_generation(df, n, S, Velocity, l, w, h, old_generation = None): #генерация потомков и их мутация
    
    new_generation_genoms = []
    
    if old_generation == None:
        old_generation = generate_first_epoch(df, n, S, Velocity, l, w, h)
    
    if old_generation != None:
        for _ in range(gen_num):
            #кол-во родителей
            mother, father = random.choices(old_generation, [k['prob'] for k in old_generation], k = 2))

            children = []
            
            for i in range(len(mother['coeffs'])-1):
                children.extend(crossover(mother, father, i))
                
            childrens_probs = optimized_probs(children)
            
            index = who_will_survive(childrens_probs)
            
            new_generation_genoms.append(mutation_bias(childrens_probs[index]))
            
        
        new_generation_probs = optimized_probs(new_generation_genoms)
        population = len(new_generation_genoms)
        
        return [{'prob': new_generation_probs[i], 'coeffs': new_generation_genoms[i]} for i in range(population)]

# %%
#!!!!!!!! реализовать перебор ген-алг оптимизаций по n (кол-во роутеров), вывести скор для их сравнения 
# где помимо прочих параметров n будет ролять как выбрать лучшее замощение с использованием n как можно меньшим

def get_loss(new_samlpe, last_sample, n): #ещё какие-то параметры, пока не ясно какие
    pass


#l, w, h = [int(i) for i in input.split()]
l, w, h = 200, 300, 5
S, Velocity = l*h, 5

n = 20
gen_num = 20


#stop_bruteforce = ?????????????????????????
loss = stop_bruteforce - 1
losses = []

while loss < stop_bruteforce:
    samlpe = gen_alg(df, n, S, Velocity, l, w, h, stop_score, max_epochs = gen_num)
    loss = get_loss(samlpe, losses[-1], n) 
    losses.append(loss)
    n+=1
